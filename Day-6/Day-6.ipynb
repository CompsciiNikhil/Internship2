# %% [markdown]
# ## DNN Example for Fashion MNIST Dataset

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load Fashion MNIST Dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
# Class labels
class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Plot label distribution
def plot_label_distribution(labels, class_names):
    plt.figure(figsize=(10, 5))
    sns.countplot(x=labels, hue=labels, palette="viridis", legend=False)
    plt.xticks(np.arange(10), class_names, rotation=45)
    plt.title("Distribution of Fashion MNIST Classes")
    plt.xlabel("Class Name")
    plt.ylabel("Count")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Plot sample images
def plot_fashion_mnist(images, labels, class_names, rows=5, cols=5):
    plt.figure(figsize=(2 * cols, 2.5 * rows))
    for i in range(rows * cols):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(images[i], cmap='gray')
        plt.title(class_names[labels[i]], fontsize=9)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_label_distribution(y_train, class_names)
plot_fashion_mnist(x_train, y_train, class_names)

# %%
# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Flatten input images
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# %%
def create_model():
    initializer = tf.keras.initializers.HeNormal()
    model = models.Sequential()
    model.add(layers.Input(shape=(784,)))

    # Add 10 hidden layers
    for _ in range(10):
        model.add(layers.Dense(128, kernel_initializer=initializer))
        model.add(layers.BatchNormalization())
        model.add(layers.Activation('relu'))
        model.add(layers.Dropout(0.2))

    model.add(layers.Dense(10, activation='softmax'))  # Output layer
    return model

# %%
model = create_model()
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_30 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 255,498 (998.04 KB)
#  Trainable params: 252,938 (988.04 KB)
#  Non-trainable params: 2,560 (10.00 KB)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(patience=3, factor=0.5)
]

# Use this inside .fit(...)
history = model.fit(
    x_train, y_train,
    validation_split=0.2,
    epochs=30,
    batch_size=128,
    callbacks=callbacks,
    verbose=2
)
# Out:
# Epoch 1/30
# 375/375 - 17s - 46ms/step - accuracy: 0.4982 - loss: 1.3339 - val_accuracy: 0.7622 - val_loss: 0.6478 - learning_rate: 1.0000e-03
# Epoch 2/30
# 375/375 - 6s - 16ms/step - accuracy: 0.7466 - loss: 0.7217 - val_accuracy: 0.8237 - val_loss: 0.5161 - learning_rate: 1.0000e-03
# Epoch 3/30
# 375/375 - 11s - 29ms/step - accuracy: 0.7982 - loss: 0.6030 - val_accuracy: 0.8407 - val_loss: 0.4695 - learning_rate: 1.0000e-03
# Epoch 4/30
# 375/375 - 7s - 18ms/step - accuracy: 0.8208 - loss: 0.5483 - val_accuracy: 0.8326 - val_loss: 0.4921 - learning_rate: 1.0000e-03
# Epoch 5/30
# 375/375 - 6s - 16ms/step - accuracy: 0.8307 - loss: 0.5149 - val_accuracy: 0.8234 - val_loss: 0.5013 - learning_rate: 1.0000e-03
# Epoch 6/30
# 375/375 - 11s - 30ms/step - accuracy: 0.8414 - loss: 0.4838 - val_accuracy: 0.8526 - val_loss: 0.4225 - learning_rate: 1.0000e-03
# Epoch 7/30
# 375/375 - 6s - 17ms/step - accuracy: 0.8478 - loss: 0.4597 - val_accuracy: 0.8651 - val_loss: 0.3917 - learning_rate: 1.0000e-03
# Epoch 8/30
# 375/375 - 7s - 18ms/step - accuracy: 0.8522 - loss: 0.4455 - val_accuracy: 0.8583 - val_loss: 0.4216 - learning_rate: 1.0000e-03
# Epoch 9/30
# 375/375 - 10s - 28ms/step - accuracy: 0.8564 - loss: 0.4323 - val_accuracy: 0.8654 - val_loss: 0.4047 - learning_rate: 1.0000e-03
# Epoch 10/30
# 375/375 - 11s - 28ms/step - accuracy: 0.8595 - loss: 0.4210 - val_accuracy: 0.8653 - val_loss: 0.3841 - learning_rate: 1.0000e-03
# Epoch 11/30
# 375/375 - 9s - 24ms/step - accuracy: 0.8638 - loss: 0.4088 - val_accuracy: 0.8701 - val_loss: 0.3815 - learning_rate: 1.0000e-03
# Epoch 12/30
# 375/375 - 10s - 27ms/step - accuracy: 0.8680 - loss: 0.3976 - val_accuracy: 0.8692 - val_loss: 0.3812 - learning_rate: 1.0000e-03
# Epoch 13/30
# 375/375 - 10s - 27ms/step - accuracy: 0.8719 - loss: 0.3875 - val_accuracy: 0.8511 - val_loss: 0.4240 - learning_rate: 1.0000e-03
# Epoch 14/30
# 375/375 - 7s - 19ms/step - accuracy: 0.8733 - loss: 0.3778 - val_accuracy: 0.8751 - val_loss: 0.3736 - learning_rate: 1.0000e-03
# Epoch 15/30
# 375/375 - 9s - 25ms/step - accuracy: 0.8741 - loss: 0.3699 - val_accuracy: 0.8788 - val_loss: 0.3550 - learning_rate: 1.0000e-03
# Epoch 16/30
# 375/375 - 7s - 18ms/step - accuracy: 0.8799 - loss: 0.3582 - val_accuracy: 0.8783 - val_loss: 0.3596 - learning_rate: 1.0000e-03
# Epoch 17/30
# 375/375 - 7s - 19ms/step - accuracy: 0.8806 - loss: 0.3532 - val_accuracy: 0.8788 - val_loss: 0.3459 - learning_rate: 1.0000e-03
# Epoch 18/30
# 375/375 - 9s - 24ms/step - accuracy: 0.8829 - loss: 0.3481 - val_accuracy: 0.8849 - val_loss: 0.3490 - learning_rate: 1.0000e-03
# Epoch 19/30
# 375/375 - 10s - 26ms/step - accuracy: 0.8841 - loss: 0.3435 - val_accuracy: 0.8815 - val_loss: 0.3536 - learning_rate: 1.0000e-03
# Epoch 20/30
# 375/375 - 11s - 28ms/step - accuracy: 0.8849 - loss: 0.3397 - val_accuracy: 0.8827 - val_loss: 0.3513 - learning_rate: 1.0000e-03
# Epoch 21/30
# 375/375 - 11s - 29ms/step - accuracy: 0.8905 - loss: 0.3162 - val_accuracy: 0.8881 - val_loss: 0.3312 - learning_rate: 5.0000e-04
# Epoch 22/30
# 375/375 - 7s - 17ms/step - accuracy: 0.8948 - loss: 0.3047 - val_accuracy: 0.8887 - val_loss: 0.3325 - learning_rate: 5.0000e-04
# Epoch 23/30
# 375/375 - 10s - 26ms/step - accuracy: 0.8981 - loss: 0.2997 - val_accuracy: 0.8866 - val_loss: 0.3304 - learning_rate: 5.0000e-04
# Epoch 24/30
# 375/375 - 7s - 19ms/step - accuracy: 0.8985 - loss: 0.2983 - val_accuracy: 0.8915 - val_loss: 0.3310 - learning_rate: 5.0000e-04
# Epoch 25/30
# 375/375 - 6s - 16ms/step - accuracy: 0.8999 - loss: 0.2931 - val_accuracy: 0.8885 - val_loss: 0.3216 - learning_rate: 5.0000e-04
# Epoch 26/30
# 375/375 - 7s - 19ms/step - accuracy: 0.9028 - loss: 0.2864 - val_accuracy: 0.8917 - val_loss: 0.3339 - learning_rate: 5.0000e-04
# Epoch 27/30
# 375/375 - 10s - 28ms/step - accuracy: 0.9021 - loss: 0.2844 - val_accuracy: 0.8902 - val_loss: 0.3296 - learning_rate: 5.0000e-04
# Epoch 28/30
# 375/375 - 6s - 16ms/step - accuracy: 0.9046 - loss: 0.2826 - val_accuracy: 0.8932 - val_loss: 0.3246 - learning_rate: 5.0000e-04
# Epoch 29/30
# 375/375 - 7s - 19ms/step - accuracy: 0.9080 - loss: 0.2683 - val_accuracy: 0.8921 - val_loss: 0.3208 - learning_rate: 2.5000e-04
# Epoch 30/30
# 375/375 - 10s - 27ms/step - accuracy: 0.9090 - loss: 0.2678 - val_accuracy: 0.8952 - val_loss: 0.3188 - learning_rate: 2.5000e-04

# %%
# Plot Training History
def plot_history(history):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)

# %%
# Evaluate Model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Test Accuracy: 0.8887

# %%
# Predict and visualize sample results
def show_predictions(model, x_test, y_test):
    preds = model.predict(x_test)
    pred_classes = np.argmax(preds, axis=1)

    plt.figure(figsize=(12, 6))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
        plt.title(f"True: {class_names[y_test[i]]}\nPred: {class_names[pred_classes[i]]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

show_predictions(model, x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# ## ResNet (DNN) Example for Fashion MNIST Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Add, Activation, Flatten
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Flatten the images for DNN
x_train_flat = x_train.reshape(-1, 28*28)
x_test_flat = x_test.reshape(-1, 28*28)

# Visualize some samples
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[np.argmax(y_train[i])])
plt.show()

# %%
# Standard DNN Model
def create_dnn():
    inputs = Input(shape=(784,))
    x = inputs
    for _ in range(10):  # Add 10 hidden layers
        x = Dense(128, activation='relu', kernel_initializer='he_normal')(x)
    outputs = Dense(10, activation='softmax')(x)
    return Model(inputs, outputs)



# ResNet-style DNN Model (with residual connections)
def create_resnet_dnn():
    inputs = Input(shape=(784,))

    # Initial dense layer
    x = Dense(256, activation='relu')(inputs)

    # Residual block 1
    x1 = Dense(256, activation='relu')(x)
    x2 = Dense(256, activation='relu')(x1)
    res1 = Add()([x, x2])  # Skip connection
    res1 = Activation('relu')(res1)

    # Residual block 2
    x3 = Dense(128, activation='relu')(res1)
    x4 = Dense(128, activation='relu')(x3)
    # Need to match dimensions for the skip connection
    res1_down = Dense(128, activation='relu')(res1)  # Projection to match dimensions
    res2 = Add()([res1_down, x4])
    res2 = Activation('relu')(res2)

    # Final layers
    x_final = Dense(64, activation='relu')(res2)
    outputs = Dense(10, activation='softmax')(x_final)

    return Model(inputs, outputs)

# %%
# Create and compile models
dnn_model = create_dnn()
resnet_model = create_resnet_dnn()

dnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
resnet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train models
dnn_history = dnn_model.fit(x_train_flat, y_train,
                            epochs=10,
                            batch_size=128,
                            validation_split=0.2,
                            verbose=1)

resnet_history = resnet_model.fit(x_train_flat, y_train,
                                 epochs=10,
                                 batch_size=128,
                                 validation_split=0.2,
                                 verbose=1)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7087 - loss: 0.8087 - val_accuracy: 0.8451 - val_loss: 0.4306
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8513 - loss: 0.4128 - val_accuracy: 0.8639 - val_loss: 0.3871
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8637 - loss: 0.3700 - val_accuracy: 0.8695 - val_loss: 0.3689
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8731 - loss: 0.3492 - val_accuracy: 0.8757 - val_loss: 0.3467
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8829 - loss: 0.3178 - val_accuracy: 0.8729 - val_loss: 0.3551
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8851 - loss: 0.3124 - val_accuracy: 0.8787 - val_loss: 0.3657
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8892 - loss: 0.2983 - val_accuracy: 0.8768 - val_loss: 0.3431
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8946 - loss: 0.2802 - val_accuracy: 0.8759 - val_loss: 0.3529
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8947 - loss: 0.2815 - val_accuracy: 0.8759 - val_loss: 0.3543
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9023 - loss: 0.2693 - val_accuracy: 0.8770 - val_loss: 0.3475
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7335 - loss: 0.7665 - val_accuracy: 0.8517 - val_loss: 0.4038
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8624 - loss: 0.3789 - val_accuracy: 0.8700 - val_loss: 0.3601
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8763 - loss: 0.3341 - val_accuracy: 0.8673 - val_loss: 0.3607
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8900 - loss: 0.2978 - val_accuracy: 0.8796 - val_loss: 0.3309
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8927 - loss: 0.2914 - val_accuracy: 0.8826 - val_loss: 0.3295
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8977 - loss: 0.2745 - val_accuracy: 0.8812 - val_loss: 0.3267
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9040 - loss: 0.2522 - val_accuracy: 0.8826 - val_loss: 0.3375
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9043 - loss: 0.2475 - val_accuracy: 0.8834 - val_loss: 0.3254
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9116 - loss: 0.2334 - val_accuracy: 0.8783 - val_loss: 0.3456
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9124 - loss: 0.2299 - val_accuracy: 0.8865 - val_loss: 0.3180

# %%
# Plot training history
def plot_history(history, title):
    plt.figure(figsize=(12, 4))
    plt.suptitle(title)

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.legend()

    plt.show()

# %%
plot_history(dnn_history, 'Standard DNN Training')
plot_history(resnet_history, 'ResNet-style DNN Training')

# %%
# Evaluate on test set
dnn_test_loss, dnn_test_acc = dnn_model.evaluate(x_test_flat, y_test, verbose=0)
resnet_test_loss, resnet_test_acc = resnet_model.evaluate(x_test_flat, y_test, verbose=0)

# %%
print(f"Standard DNN Test Accuracy: {dnn_test_acc:.4f}")
print(f"ResNet-style DNN Test Accuracy: {resnet_test_acc:.4f}")
# Out:
# Standard DNN Test Accuracy: 0.8692
# ResNet-style DNN Test Accuracy: 0.8796

# %%
# Make predictions and visualize some results
def plot_predictions(model, x_test, y_test, num_images=5):
    predictions = model.predict(x_test)
    plt.figure(figsize=(15, 3*num_images))
    for i in range(num_images):
        plt.subplot(num_images, 1, i+1)
        plt.imshow(x_test[i].reshape(28, 28), cmap=plt.cm.binary)
        pred_label = np.argmax(predictions[i])
        true_label = np.argmax(y_test[i])
        color = 'green' if pred_label == true_label else 'red'
        plt.xlabel(f"Predicted: {class_names[pred_label]} (True: {class_names[true_label]})", color=color)
    plt.show()

print("\nStandard DNN Predictions:")
plot_predictions(dnn_model, x_test_flat, y_test)

print("\nResNet-style DNN Predictions:")
plot_predictions(resnet_model, x_test_flat, y_test)
# Out:
# Standard DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ResNet-style DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ##While executing the Fashion MNIST classification code:
#
# The dataset is balanced but has visually similar classes (e.g., Shirt vs T-shirt).
#
# The standard DNN achieves ~88–89% accuracy but may overfit.
#
# The ResNet-style DNN with skip connections performs better (~90–92%) and generalizes well.
#
# Batch normalization, dropout, and learning rate scheduling improve stability and accuracy.
